# %% [markdown]
# # Scraping Ulasan Google Play Store dengan Python
#
# ## Deskripsi Proyek
# Notebook ini bertujuan untuk mengambil ulasan dari aplikasi **Wuthering Waves** (ID: `com.kurogame.wutheringwaves.global`) di Google Play Store menggunakan library `google-play-scraper`. Data yang dikumpulkan akan disimpan dalam format CSV untuk analisis lebih lanjut. Proses ini mencakup pengaturan parameter, scraping data, dan penyimpanan hasil.
#
# ## Informasi Pengembang
# - **Nama**: Michael Teguh Carlo Simbolon
# - **Cohort ID**: MS155D5Y0583
# - **Tanggal**: 12 Maret 2025
#
# ## Prasyarat
# Pastikan Anda telah menginstal library berikut sebelum menjalankan notebook ini:
# ```bash
# pip install google-play-scraper pandas
# ```
# - **`google-play-scraper`**: Untuk mengambil data ulasan dari Google Play Store.
# - **`pandas`**: Untuk mengelola dan menyimpan data dalam format tabel.

# %% [markdown]
# ## 1. Mengimpor Library yang Dibutuhkan
#
# Langkah pertama adalah mengimpor library yang akan digunakan dalam proses scraping.

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# Verifikasi bahwa library berhasil diimpor
print("Library berhasil diimpor.")
# Out:
# Library berhasil diimpor.

# %% [markdown]
# ## 2. Mengatur Parameter Scraping
#
# Di sini, kita mendefinisikan parameter utama untuk proses scraping.
#
# ### Penjelasan Parameter:
# - **`app_id`**: ID unik aplikasi di Google Play Store (contoh: `com.kurogame.wutheringwaves.global` untuk Wuthering Waves).
# - **`max_reviews`**: Jumlah maksimum ulasan yang akan diambil (10.000 ulasan).
# - **`batch_size`**: Jumlah ulasan yang diambil dalam satu permintaan (100 ulasan per batch, sesuai batasan library).

# %%
app_id = "com.kurogame.wutheringwaves.global"
max_reviews = 10000
batch_size = 100

# Menampilkan parameter untuk verifikasi
print(f"App ID: {app_id}")
print(f"Jumlah maksimum ulasan: {max_reviews}")
print(f"Ukuran batch: {batch_size}")
# Out:
# App ID: com.kurogame.wutheringwaves.global
# Jumlah maksimum ulasan: 10000
# Ukuran batch: 100

# %% [markdown]
# ## 3. Inisialisasi Variabel
#
# Sebelum memulai scraping, kita perlu menginisialisasi variabel yang akan digunakan.
#
# ### Penjelasan Variabel:
# - **`data`**: List kosong untuk menyimpan ulasan dalam bentuk dictionary.
# - **`counter`**: Penghitung jumlah ulasan yang telah diambil.
# - **`continuation_token`**: Token untuk melanjutkan pengambilan data dari batch sebelumnya (awalnya `None`).

# %%
data = []
counter = 0
continuation_token = None

# Verifikasi inisialisasi
print("Variabel berhasil diinisialisasi.")
# Out:
# Variabel berhasil diinisialisasi.

# %% [markdown]
# ## 4. Proses Scraping Ulasan
#
# Bagian ini berisi logika utama untuk mengambil ulasan dari Google Play Store.
#
# ### Penjelasan Proses:
# - **Notifikasi Awal**: Menampilkan pesan bahwa proses scraping dimulai.
# - **Loop Utama**: Menggunakan `while` untuk mengambil ulasan hingga mencapai `max_reviews` atau tidak ada lagi data.
# - **Fungsi `reviews`**:
#   - **`app_id`**: ID aplikasi target.
#   - **`lang='id'`**: Bahasa ulasan (Indonesia).
#   - **`country='id'`**: Negara asal ulasan (Indonesia).
#   - **`sort=Sort.NEWEST`**: Urutan ulasan dari terbaru.
#   - **`count=batch_size`**: Jumlah ulasan per batch.
#   - **`continuation_token`**: Token untuk melanjutkan dari batch sebelumnya.
# - **Pengolahan Data**: Setiap ulasan disimpan dalam dictionary dengan kolom:
#   - `Username`: Nama pengguna.
#   - `Text`: Isi ulasan.
#   - `Rating`: Skor (1-5).
#   - `Tanggal`: Waktu ulasan dibuat.
#   - `Jumlah Suka`: Jumlah suka pada ulasan.
#   - `Balasan Pengembang`: Tanggapan dari pengembang (jika ada).
#   - `Versi Aplikasi`: Versi aplikasi saat ulasan dibuat (jika ada).
# - **Kondisi Berhenti**:
#   - Jika `counter >= max_reviews`: Berhenti saat jumlah maksimum tercapai.
#   - Jika `continuation_token` kosong: Berhenti saat tidak ada lagi data.

# %%
print("Memulai proses scraping...")

while counter < max_reviews:
    result, continuation_token = reviews(
        app_id,
        lang='id',
        country='id',
        sort=Sort.NEWEST,
        count=batch_size,
        continuation_token=continuation_token if counter > 0 else None
    )
    
    for review in result:
        data.append({
            "Username": review["userName"],
            "Text": review["content"],
            "Rating": review["score"],
            "Tanggal": review["at"],
            "Jumlah Suka": review["thumbsUpCount"],
            "Balasan Pengembang": review["replyContent"] if review["replyContent"] else None,
            "Versi Aplikasi": review["reviewCreatedVersion"] if review["reviewCreatedVersion"] else None
        })
        counter += 1
        print(f"Sukses ambil data ke - {counter}")
        
        if counter >= max_reviews:
            break
    
    if not continuation_token:
        print("Tidak ada lagi ulasan yang tersedia.")
        break
# Out:
# Memulai proses scraping...
# Sukses ambil data ke - 1
# Sukses ambil data ke - 2
# Sukses ambil data ke - 3
# Sukses ambil data ke - 4
# Sukses ambil data ke - 5
# Sukses ambil data ke - 6
# Sukses ambil data ke - 7
# Sukses ambil data ke - 8
# Sukses ambil data ke - 9
# Sukses ambil data ke - 10
# Sukses ambil data ke - 11
# Sukses ambil data ke - 12
# Sukses ambil data ke - 13
# Sukses ambil data ke - 14
# Sukses ambil data ke - 15
# Sukses ambil data ke - 16
# Sukses ambil data ke - 17
# Sukses ambil data ke - 18
# Sukses ambil data ke - 19
# Sukses ambil data ke - 20
# Sukses ambil data ke - 21
# Sukses ambil data ke - 22
# Sukses ambil data ke - 23
# Sukses ambil data ke - 24
# Sukses ambil data ke - 25
# Sukses ambil data ke - 26
# Sukses ambil data ke - 27
# Sukses ambil data ke - 28
# Sukses ambil data ke - 29
# Sukses ambil data ke - 30
# Sukses ambil data ke - 31
# Sukses ambil data ke - 32
# Sukses ambil data ke - 33
# Sukses ambil data ke - 34
# Sukses ambil data ke - 35
# Sukses ambil data ke - 36
# Sukses ambil data ke - 37
# Sukses ambil data ke - 38
# Sukses ambil data ke - 39
# Sukses ambil data ke - 40
# Sukses ambil data ke - 41
# Sukses ambil data ke - 42
# Sukses ambil data ke - 43
# Sukses ambil data ke - 44
# Sukses ambil data ke - 45
# Sukses ambil data ke - 46
# Sukses ambil data ke - 47
# Sukses ambil data ke - 48
# Sukses ambil data ke - 49
# Sukses ambil data ke - 50
# Sukses ambil data ke - 51
# Sukses ambil data ke - 52
# Sukses ambil data ke - 53
# Sukses ambil data ke - 54
# Sukses ambil data ke - 55
# Sukses ambil data ke - 56
# Sukses ambil data ke - 57
# Sukses ambil data ke - 58
# Sukses ambil data ke - 59
# Sukses ambil data ke - 60
# Sukses ambil data ke - 61
# Sukses ambil data ke - 62
# Sukses ambil data ke - 63
# Sukses ambil data ke - 64
# Sukses ambil data ke - 65
# Sukses ambil data ke - 66
# Sukses ambil data ke - 67
# Sukses ambil data ke - 68
# Sukses ambil data ke - 69
# Sukses ambil data ke - 70
# Sukses ambil data ke - 71
# Sukses ambil data ke - 72
# Sukses ambil data ke - 73
# Sukses ambil data ke - 74
# Sukses ambil data ke - 75
# Sukses ambil data ke - 76
# Sukses ambil data ke - 77
# Sukses ambil data ke - 78
# Sukses ambil data ke - 79
# Sukses ambil data ke - 80
# Sukses ambil data ke - 81
# Sukses ambil data ke - 82
# Sukses ambil data ke - 83
# Sukses ambil data ke - 84
# Sukses ambil data ke - 85
# Sukses ambil data ke - 86
# Sukses ambil data ke - 87
# Sukses ambil data ke - 88
# Sukses ambil data ke - 89
# Sukses ambil data ke - 90
# Sukses ambil data ke - 91
# Sukses ambil data ke - 92
# Sukses ambil data ke - 93
# Sukses ambil data ke - 94
# Sukses ambil data ke - 95
# Sukses ambil data ke - 96
# Sukses ambil data ke - 97
# Sukses ambil data ke - 98
# Sukses ambil data ke - 99
# Sukses ambil data ke - 100
# Sukses ambil data ke - 101
# Sukses ambil data ke - 102
# Sukses ambil data ke - 103
# Sukses ambil data ke - 104
# Sukses ambil data ke - 105
# Sukses ambil data ke - 106
# Sukses ambil data ke - 107
# Sukses ambil data ke - 108
# Sukses ambil data ke - 109
# Sukses ambil data ke - 110
# Sukses ambil data ke - 111
# Sukses ambil data ke - 112
# Sukses ambil data ke - 113
# Sukses ambil data ke - 114
# Sukses ambil data ke - 115
# Sukses ambil data ke - 116
# Sukses ambil data ke - 117
# Sukses ambil data ke - 118
# Sukses ambil data ke - 119
# Sukses ambil data ke - 120
# Sukses ambil data ke - 121
# Sukses ambil data ke - 122
# Sukses ambil data ke - 123
# Sukses ambil data ke - 124
# Sukses ambil data ke - 125
# Sukses ambil data ke - 126
# Sukses ambil data ke - 127
# Sukses ambil data ke - 128
# Sukses ambil data ke - 129
# Sukses ambil data ke - 130
# Sukses ambil data ke - 131
# Sukses ambil data ke - 132
# Sukses ambil data ke - 133
# Sukses ambil data ke - 134
# Sukses ambil data ke - 135
# Sukses ambil data ke - 136
# Sukses ambil data ke - 137
# Sukses ambil data ke - 138
# Sukses ambil data ke - 139
# Sukses ambil data ke - 140
# Sukses ambil data ke - 141
# Sukses ambil data ke - 142
# Sukses ambil data ke - 143
# Sukses ambil data ke - 144
# Sukses ambil data ke - 145
# Sukses ambil data ke - 146
# Sukses ambil data ke - 147
# Sukses ambil data ke - 148
# Sukses ambil data ke - 149
# Sukses ambil data ke - 150
# Sukses ambil data ke - 151
# Sukses ambil data ke - 152
# Sukses ambil data ke - 153
# Sukses ambil data ke - 154
# Sukses ambil data ke - 155
# Sukses ambil data ke - 156
# Sukses ambil data ke - 157
# Sukses ambil data ke - 158
# Sukses ambil data ke - 159
# Sukses ambil data ke - 160
# Sukses ambil data ke - 161
# Sukses ambil data ke - 162
# Sukses ambil data ke - 163
# Sukses ambil data ke - 164
# Sukses ambil data ke - 165
# Sukses ambil data ke - 166
# Sukses ambil data ke - 167
# Sukses ambil data ke - 168
# Sukses ambil data ke - 169
# Sukses ambil data ke - 170
# Sukses ambil data ke - 171
# Sukses ambil data ke - 172
# Sukses ambil data ke - 173
# Sukses ambil data ke - 174
# Sukses ambil data ke - 175
# Sukses ambil data ke - 176
# Sukses ambil data ke - 177
# Sukses ambil data ke - 178
# Sukses ambil data ke - 179
# Sukses ambil data ke - 180
# Sukses ambil data ke - 181
# Sukses ambil data ke - 182
# Sukses ambil data ke - 183
# Sukses ambil data ke - 184
# Sukses ambil data ke - 185
# Sukses ambil data ke - 186
# Sukses ambil data ke - 187
# Sukses ambil data ke - 188
# Sukses ambil data ke - 189
# Sukses ambil data ke - 190
# Sukses ambil data ke - 191
# Sukses ambil data ke - 192
# Sukses ambil data ke - 193
# Sukses ambil data ke - 194
# Sukses ambil data ke - 195
# Sukses ambil data ke - 196
# Sukses ambil data ke - 197
# Sukses ambil data ke - 198
# Sukses ambil data ke - 199
# Sukses ambil data ke - 200
# Sukses ambil data ke - 201
# Sukses ambil data ke - 202
# Sukses ambil data ke - 203
# Sukses ambil data ke - 204
# Sukses ambil data ke - 205
# Sukses ambil data ke - 206
# Sukses ambil data ke - 207
# Sukses ambil data ke - 208
# Sukses ambil data ke - 209
# Sukses ambil data ke - 210
# Sukses ambil data ke - 211
# Sukses ambil data ke - 212
# Sukses ambil data ke - 213
# Sukses ambil data ke - 214
# Sukses ambil data ke - 215
# Sukses ambil data ke - 216
# Sukses ambil data ke - 217
# Sukses ambil data ke - 218
# Sukses ambil data ke - 219
# Sukses ambil data ke - 220
# Sukses ambil data ke - 221
# Sukses ambil data ke - 222
# Sukses ambil data ke - 223
# Sukses ambil data ke - 224
# Sukses ambil data ke - 225
# Sukses ambil data ke - 226
# Sukses ambil data ke - 227
# Sukses ambil data ke - 228
# Sukses ambil data ke - 229
# Sukses ambil data ke - 230
# Sukses ambil data ke - 231
# Sukses ambil data ke - 232
# Sukses ambil data ke - 233
# Sukses ambil data ke - 234
# Sukses ambil data ke - 235
# Sukses ambil data ke - 236
# Sukses ambil data ke - 237
# Sukses ambil data ke - 238
# Sukses ambil data ke - 239
# Sukses ambil data ke - 240
# Sukses ambil data ke - 241
# Sukses ambil data ke - 242
# Sukses ambil data ke - 243
# Sukses ambil data ke - 244
# Sukses ambil data ke - 245
# Sukses ambil data ke - 246
# Sukses ambil data ke - 247
# Sukses ambil data ke - 248
# Sukses ambil data ke - 249
# Sukses ambil data ke - 250
# Sukses ambil data ke - 251
# Sukses ambil data ke - 252
# Sukses ambil data ke - 253
# Sukses ambil data ke - 254
# Sukses ambil data ke - 255
# Sukses ambil data ke - 256
# Sukses ambil data ke - 257
# Sukses ambil data ke - 258
# Sukses ambil data ke - 259
# Sukses ambil data ke - 260
# Sukses ambil data ke - 261
# Sukses ambil data ke - 262
# Sukses ambil data ke - 263
# Sukses ambil data ke - 264
# Sukses ambil data ke - 265
# Sukses ambil data ke - 266
# Sukses ambil data ke - 267
# Sukses ambil data ke - 268
# Sukses ambil data ke - 269
# Sukses ambil data ke - 270
# Sukses ambil data ke - 271
# Sukses ambil data ke - 272
# Sukses ambil data ke - 273
# Sukses ambil data ke - 274
# Sukses ambil data ke - 275
# Sukses ambil data ke - 276
# Sukses ambil data ke - 277
# Sukses ambil data ke - 278
# Sukses ambil data ke - 279
# Sukses ambil data ke - 280
# Sukses ambil data ke - 281
# Sukses ambil data ke - 282
# Sukses ambil data ke - 283
# Sukses ambil data ke - 284
# Sukses ambil data ke - 285
# Sukses ambil data ke - 286
# Sukses ambil data ke - 287
# Sukses ambil data ke - 288
# Sukses ambil data ke - 289
# Sukses ambil data ke - 290
# Sukses ambil data ke - 291
# Sukses ambil data ke - 292
# Sukses ambil data ke - 293
# Sukses ambil data ke - 294
# Sukses ambil data ke - 295
# Sukses ambil data ke - 296
# Sukses ambil data ke - 297
# Sukses ambil data ke - 298
# Sukses ambil data ke - 299
# Sukses ambil data ke - 300
# Sukses ambil data ke - 301
# Sukses ambil data ke - 302
# Sukses ambil data ke - 303
# Sukses ambil data ke - 304
# Sukses ambil data ke - 305
# Sukses ambil data ke - 306
# Sukses ambil data ke - 307
# Sukses ambil data ke - 308
# Sukses ambil data ke - 309
# Sukses ambil data ke - 310
# Sukses ambil data ke - 311
# Sukses ambil data ke - 312
# Sukses ambil data ke - 313
# Sukses ambil data ke - 314
# Sukses ambil data ke - 315
# Sukses ambil data ke - 316
# Sukses ambil data ke - 317
# Sukses ambil data ke - 318
# Sukses ambil data ke - 319
# Sukses ambil data ke - 320
# Sukses ambil data ke - 321
# Sukses ambil data ke - 322
# Sukses ambil data ke - 323
# Sukses ambil data ke - 324
# Sukses ambil data ke - 325
# Sukses ambil data ke - 326
# Sukses ambil data ke - 327
# Sukses ambil data ke - 328
# Sukses ambil data ke - 329
# Sukses ambil data ke - 330
# Sukses ambil data ke - 331
# Sukses ambil data ke - 332
# Sukses ambil data ke - 333
# Sukses ambil data ke - 334
# Sukses ambil data ke - 335
# Sukses ambil data ke - 336
# Sukses ambil data ke - 337
# Sukses ambil data ke - 338
# Sukses ambil data ke - 339
# Sukses ambil data ke - 340
# Sukses ambil data ke - 341
# Sukses ambil data ke - 342
# Sukses ambil data ke - 343
# Sukses ambil data ke - 344
# Sukses ambil data ke - 345
# Sukses ambil data ke - 346
# Sukses ambil data ke - 347
# Sukses ambil data ke - 348
# Sukses ambil data ke - 349
# Sukses ambil data ke - 350
# Sukses ambil data ke - 351
# Sukses ambil data ke - 352
# Sukses ambil data ke - 353
# Sukses ambil data ke - 354
# Sukses ambil data ke - 355
# Sukses ambil data ke - 356
# Sukses ambil data ke - 357
# Sukses ambil data ke - 358
# Sukses ambil data ke - 359
# Sukses ambil data ke - 360
# Sukses ambil data ke - 361
# Sukses ambil data ke - 362
# Sukses ambil data ke - 363
# Sukses ambil data ke - 364
# Sukses ambil data ke - 365
# Sukses ambil data ke - 366
# Sukses ambil data ke - 367
# Sukses ambil data ke - 368
# Sukses ambil data ke - 369
# Sukses ambil data ke - 370
# Sukses ambil data ke - 371
# Sukses ambil data ke - 372
# Sukses ambil data ke - 373
# Sukses ambil data ke - 374
# Sukses ambil data ke - 375
# Sukses ambil data ke - 376
# Sukses ambil data ke - 377
# Sukses ambil data ke - 378
# Sukses ambil data ke - 379
# Sukses ambil data ke - 380
# Sukses ambil data ke - 381
# Sukses ambil data ke - 382
# Sukses ambil data ke - 383
# Sukses ambil data ke - 384
# Sukses ambil data ke - 385
# Sukses ambil data ke - 386
# Sukses ambil data ke - 387
# Sukses ambil data ke - 388
# Sukses ambil data ke - 389
# Sukses ambil data ke - 390
# Sukses ambil data ke - 391
# Sukses ambil data ke - 392
# Sukses ambil data ke - 393
# Sukses ambil data ke - 394
# Sukses ambil data ke - 395
# Sukses ambil data ke - 396
# Sukses ambil data ke - 397
# Sukses ambil data ke - 398
# Sukses ambil data ke - 399
# Sukses ambil data ke - 400
# Sukses ambil data ke - 401
# Sukses ambil data ke - 402
# Sukses ambil data ke - 403
# Sukses ambil data ke - 404
# Sukses ambil data ke - 405
# Sukses ambil data ke - 406
# Sukses ambil data ke - 407
# Sukses ambil data ke - 408
# Sukses ambil data ke - 409
# Sukses ambil data ke - 410
# Sukses ambil data ke - 411
# Sukses ambil data ke - 412
# Sukses ambil data ke - 413
# Sukses ambil data ke - 414
# Sukses ambil data ke - 415
# Sukses ambil data ke - 416
# Sukses ambil data ke - 417
# Sukses ambil data ke - 418
# Sukses ambil data ke - 419
# Sukses ambil data ke - 420
# Sukses ambil data ke - 421
# Sukses ambil data ke - 422
# Sukses ambil data ke - 423
# Sukses ambil data ke - 424
# Sukses ambil data ke - 425
# Sukses ambil data ke - 426
# Sukses ambil data ke - 427
# Sukses ambil data ke - 428
# Sukses ambil data ke - 429
# Sukses ambil data ke - 430
# Sukses ambil data ke - 431
# Sukses ambil data ke - 432
# Sukses ambil data ke - 433
# Sukses ambil data ke - 434
# Sukses ambil data ke - 435
# Sukses ambil data ke - 436
# Sukses ambil data ke - 437
# Sukses ambil data ke - 438
# Sukses ambil data ke - 439
# Sukses ambil data ke - 440
# Sukses ambil data ke - 441
# Sukses ambil data ke - 442
# Sukses ambil data ke - 443
# Sukses ambil data ke - 444
# Sukses ambil data ke - 445
# Sukses ambil data ke - 446
# Sukses ambil data ke - 447
# Sukses ambil data ke - 448
# Sukses ambil data ke - 449
# Sukses ambil data ke - 450
# Sukses ambil data ke - 451
# Sukses ambil data ke - 452
# Sukses ambil data ke - 453
# Sukses ambil data ke - 454
# Sukses ambil data ke - 455
# Sukses ambil data ke - 456
# Sukses ambil data ke - 457
# Sukses ambil data ke - 458
# Sukses ambil data ke - 459
# Sukses ambil data ke - 460
# Sukses ambil data ke - 461
# Sukses ambil data ke - 462
# Sukses ambil data ke - 463
# Sukses ambil data ke - 464
# Sukses ambil data ke - 465
# Sukses ambil data ke - 466
# Sukses ambil data ke - 467
# Sukses ambil data ke - 468
# Sukses ambil data ke - 469
# Sukses ambil data ke - 470
# Sukses ambil data ke - 471
# Sukses ambil data ke - 472
# Sukses ambil data ke - 473
# Sukses ambil data ke - 474
# Sukses ambil data ke - 475
# Sukses ambil data ke - 476
# Sukses ambil data ke - 477
# Sukses ambil data ke - 478
# Sukses ambil data ke - 479
# Sukses ambil data ke - 480
# Sukses ambil data ke - 481
# Sukses ambil data ke - 482
# Sukses ambil data ke - 483
# Sukses ambil data ke - 484
# Sukses ambil data ke - 485
# Sukses ambil data ke - 486
# Sukses ambil data ke - 487
# Sukses ambil data ke - 488
# Sukses ambil data ke - 489
# Sukses ambil data ke - 490
# Sukses ambil data ke - 491
# Sukses ambil data ke - 492
# Sukses ambil data ke - 493
# Sukses ambil data ke - 494
# Sukses ambil data ke - 495
# Sukses ambil data ke - 496
# Sukses ambil data ke - 497
# Sukses ambil data ke - 498
# Sukses ambil data ke - 499
# Sukses ambil data ke - 500
# Sukses ambil data ke - 501
# Sukses ambil data ke - 502
# Sukses ambil data ke - 503
# Sukses ambil data ke - 504
# Sukses ambil data ke - 505
# Sukses ambil data ke - 506
# Sukses ambil data ke - 507
# Sukses ambil data ke - 508
# Sukses ambil data ke - 509
# Sukses ambil data ke - 510
# Sukses ambil data ke - 511
# Sukses ambil data ke - 512
# Sukses ambil data ke - 513
# Sukses ambil data ke - 514
# Sukses ambil data ke - 515
# Sukses ambil data ke - 516
# Sukses ambil data ke - 517
# Sukses ambil data ke - 518
# Sukses ambil data ke - 519
# Sukses ambil data ke - 520
# Sukses ambil data ke - 521
# Sukses ambil data ke - 522
# Sukses ambil data ke - 523
# Sukses ambil data ke - 524
# Sukses ambil data ke - 525
# Sukses ambil data ke - 526
# Sukses ambil data ke - 527
# Sukses ambil data ke - 528
# Sukses ambil data ke - 529
# Sukses ambil data ke - 530
# Sukses ambil data ke - 531
# Sukses ambil data ke - 532
# Sukses ambil data ke - 533
# Sukses ambil data ke - 534
# Sukses ambil data ke - 535
# Sukses ambil data ke - 536
# Sukses ambil data ke - 537
# Sukses ambil data ke - 538
# Sukses ambil data ke - 539
# Sukses ambil data ke - 540
# Sukses ambil data ke - 541
# Sukses ambil data ke - 542
# Sukses ambil data ke - 543
# Sukses ambil data ke - 544
# Sukses ambil data ke - 545
# Sukses ambil data ke - 546
# Sukses ambil data ke - 547
# Sukses ambil data ke - 548
# Sukses ambil data ke - 549
# Sukses ambil data ke - 550
# Sukses ambil data ke - 551
# Sukses ambil data ke - 552
# Sukses ambil data ke - 553
# Sukses ambil data ke - 554
# Sukses ambil data ke - 555
# Sukses ambil data ke - 556
# Sukses ambil data ke - 557
# Sukses ambil data ke - 558
# Sukses ambil data ke - 559
# Sukses ambil data ke - 560
# Sukses ambil data ke - 561
# Sukses ambil data ke - 562
# Sukses ambil data ke - 563
# Sukses ambil data ke - 564
# Sukses ambil data ke - 565
# Sukses ambil data ke - 566
# Sukses ambil data ke - 567
# Sukses ambil data ke - 568
# Sukses ambil data ke - 569
# Sukses ambil data ke - 570
# Sukses ambil data ke - 571
# Sukses ambil data ke - 572
# Sukses ambil data ke - 573
# Sukses ambil data ke - 574
# Sukses ambil data ke - 575
# Sukses ambil data ke - 576
# Sukses ambil data ke - 577
# Sukses ambil data ke - 578
# Sukses ambil data ke - 579
# Sukses ambil data ke - 580
# Sukses ambil data ke - 581
# Sukses ambil data ke - 582
# Sukses ambil data ke - 583
# Sukses ambil data ke - 584
# Sukses ambil data ke - 585
# Sukses ambil data ke - 586
# Sukses ambil data ke - 587
# Sukses ambil data ke - 588
# Sukses ambil data ke - 589
# Sukses ambil data ke - 590
# Sukses ambil data ke - 591
# Sukses ambil data ke - 592
# Sukses ambil data ke - 593
# Sukses ambil data ke - 594
# Sukses ambil data ke - 595
# Sukses ambil data ke - 596
# Sukses ambil data ke - 597
# Sukses ambil data ke - 598
# Sukses ambil data ke - 599
# Sukses ambil data ke - 600
# Sukses ambil data ke - 601
# Sukses ambil data ke - 602
# Sukses ambil data ke - 603
# Sukses ambil data ke - 604
# Sukses ambil data ke - 605
# Sukses ambil data ke - 606
# Sukses ambil data ke - 607
# Sukses ambil data ke - 608
# Sukses ambil data ke - 609
# Sukses ambil data ke - 610
# Sukses ambil data ke - 611
# Sukses ambil data ke - 612
# Sukses ambil data ke - 613
# Sukses ambil data ke - 614
# Sukses ambil data ke - 615
# Sukses ambil data ke - 616
# Sukses ambil data ke - 617
# Sukses ambil data ke - 618
# Sukses ambil data ke - 619
# Sukses ambil data ke - 620
# Sukses ambil data ke - 621
# Sukses ambil data ke - 622
# Sukses ambil data ke - 623
# Sukses ambil data ke - 624
# Sukses ambil data ke - 625
# Sukses ambil data ke - 626
# Sukses ambil data ke - 627
# Sukses ambil data ke - 628
# Sukses ambil data ke - 629
# Sukses ambil data ke - 630
# Sukses ambil data ke - 631
# Sukses ambil data ke - 632
# Sukses ambil data ke - 633
# Sukses ambil data ke - 634
# Sukses ambil data ke - 635
# Sukses ambil data ke - 636
# Sukses ambil data ke - 637
# Sukses ambil data ke - 638
# Sukses ambil data ke - 639
# Sukses ambil data ke - 640
# Sukses ambil data ke - 641
# Sukses ambil data ke - 642
# Sukses ambil data ke - 643
# Sukses ambil data ke - 644
# Sukses ambil data ke - 645
# Sukses ambil data ke - 646
# Sukses ambil data ke - 647
# Sukses ambil data ke - 648
# Sukses ambil data ke - 649
# Sukses ambil data ke - 650
# Sukses ambil data ke - 651
# Sukses ambil data ke - 652
# Sukses ambil data ke - 653
# Sukses ambil data ke - 654
# Sukses ambil data ke - 655
# Sukses ambil data ke - 656
# Sukses ambil data ke - 657
# Sukses ambil data ke - 658
# Sukses ambil data ke - 659
# Sukses ambil data ke - 660
# Sukses ambil data ke - 661
# Sukses ambil data ke - 662
# Sukses ambil data ke - 663
# Sukses ambil data ke - 664
# Sukses ambil data ke - 665
# Sukses ambil data ke - 666
# Sukses ambil data ke - 667
# Sukses ambil data ke - 668
# Sukses ambil data ke - 669
# Sukses ambil data ke - 670
# Sukses ambil data ke - 671
# Sukses ambil data ke - 672
# Sukses ambil data ke - 673
# Sukses ambil data ke - 674
# Sukses ambil data ke - 675
# Sukses ambil data ke - 676
# Sukses ambil data ke - 677
# Sukses ambil data ke - 678
# Sukses ambil data ke - 679
# Sukses ambil data ke - 680
# Sukses ambil data ke - 681
# Sukses ambil data ke - 682
# Sukses ambil data ke - 683
# Sukses ambil data ke - 684
# Sukses ambil data ke - 685
# Sukses ambil data ke - 686
# Sukses ambil data ke - 687
# Sukses ambil data ke - 688
# Sukses ambil data ke - 689
# Sukses ambil data ke - 690
# Sukses ambil data ke - 691
# Sukses ambil data ke - 692
# Sukses ambil data ke - 693
# Sukses ambil data ke - 694
# Sukses ambil data ke - 695
# Sukses ambil data ke - 696
# Sukses ambil data ke - 697
# Sukses ambil data ke - 698
# Sukses ambil data ke - 699
# Sukses ambil data ke - 700
# Sukses ambil data ke - 701
# Sukses ambil data ke - 702
# Sukses ambil data ke - 703
# Sukses ambil data ke - 704
# Sukses ambil data ke - 705
# Sukses ambil data ke - 706
# Sukses ambil data ke - 707
# Sukses ambil data ke - 708
# Sukses ambil data ke - 709
# Sukses ambil data ke - 710
# Sukses ambil data ke - 711
# Sukses ambil data ke - 712
# Sukses ambil data ke - 713
# Sukses ambil data ke - 714
# Sukses ambil data ke - 715
# Sukses ambil data ke - 716
# Sukses ambil data ke - 717
# Sukses ambil data ke - 718
# Sukses ambil data ke - 719
# Sukses ambil data ke - 720
# Sukses ambil data ke - 721
# Sukses ambil data ke - 722
# Sukses ambil data ke - 723
# Sukses ambil data ke - 724
# Sukses ambil data ke - 725
# Sukses ambil data ke - 726
# Sukses ambil data ke - 727
# Sukses ambil data ke - 728
# Sukses ambil data ke - 729
# Sukses ambil data ke - 730
# Sukses ambil data ke - 731
# Sukses ambil data ke - 732
# Sukses ambil data ke - 733
# Sukses ambil data ke - 734
# Sukses ambil data ke - 735
# Sukses ambil data ke - 736
# Sukses ambil data ke - 737
# Sukses ambil data ke - 738
# Sukses ambil data ke - 739
# Sukses ambil data ke - 740
# Sukses ambil data ke - 741
# Sukses ambil data ke - 742
# Sukses ambil data ke - 743
# Sukses ambil data ke - 744
# Sukses ambil data ke - 745
# Sukses ambil data ke - 746
# Sukses ambil data ke - 747
# Sukses ambil data ke - 748
# Sukses ambil data ke - 749
# Sukses ambil data ke - 750
# Sukses ambil data ke - 751
# Sukses ambil data ke - 752
# Sukses ambil data ke - 753
# Sukses ambil data ke - 754
# Sukses ambil data ke - 755
# Sukses ambil data ke - 756
# Sukses ambil data ke - 757
# Sukses ambil data ke - 758
# Sukses ambil data ke - 759
# Sukses ambil data ke - 760
# Sukses ambil data ke - 761
# Sukses ambil data ke - 762
# Sukses ambil data ke - 763
# Sukses ambil data ke - 764
# Sukses ambil data ke - 765
# Sukses ambil data ke - 766
# Sukses ambil data ke - 767
# Sukses ambil data ke - 768
# Sukses ambil data ke - 769
# Sukses ambil data ke - 770
# Sukses ambil data ke - 771
# Sukses ambil data ke - 772
# Sukses ambil data ke - 773
# Sukses ambil data ke - 774
# Sukses ambil data ke - 775
# Sukses ambil data ke - 776
# Sukses ambil data ke - 777
# Sukses ambil data ke - 778
# Sukses ambil data ke - 779
# Sukses ambil data ke - 780
# Sukses ambil data ke - 781
# Sukses ambil data ke - 782
# Sukses ambil data ke - 783
# Sukses ambil data ke - 784
# Sukses ambil data ke - 785
# Sukses ambil data ke - 786
# Sukses ambil data ke - 787
# Sukses ambil data ke - 788
# Sukses ambil data ke - 789
# Sukses ambil data ke - 790
# Sukses ambil data ke - 791
# Sukses ambil data ke - 792
# Sukses ambil data ke - 793
# Sukses ambil data ke - 794
# Sukses ambil data ke - 795
# Sukses ambil data ke - 796
# Sukses ambil data ke - 797
# Sukses ambil data ke - 798
# Sukses ambil data ke - 799
# Sukses ambil data ke - 800
# Sukses ambil data ke - 801
# Sukses ambil data ke - 802
# Sukses ambil data ke - 803
# Sukses ambil data ke - 804
# Sukses ambil data ke - 805
# Sukses ambil data ke - 806
# Sukses ambil data ke - 807
# Sukses ambil data ke - 808
# Sukses ambil data ke - 809
# Sukses ambil data ke - 810
# Sukses ambil data ke - 811
# Sukses ambil data ke - 812
# Sukses ambil data ke - 813
# Sukses ambil data ke - 814
# Sukses ambil data ke - 815
# Sukses ambil data ke - 816
# Sukses ambil data ke - 817
# Sukses ambil data ke - 818
# Sukses ambil data ke - 819
# Sukses ambil data ke - 820
# Sukses ambil data ke - 821
# Sukses ambil data ke - 822
# Sukses ambil data ke - 823
# Sukses ambil data ke - 824
# Sukses ambil data ke - 825
# Sukses ambil data ke - 826
# Sukses ambil data ke - 827
# Sukses ambil data ke - 828
# Sukses ambil data ke - 829
# Sukses ambil data ke - 830
# Sukses ambil data ke - 831
# Sukses ambil data ke - 832
# Sukses ambil data ke - 833
# Sukses ambil data ke - 834
# Sukses ambil data ke - 835
# Sukses ambil data ke - 836
# Sukses ambil data ke - 837
# Sukses ambil data ke - 838
# Sukses ambil data ke - 839
# Sukses ambil data ke - 840
# Sukses ambil data ke - 841
# Sukses ambil data ke - 842
# Sukses ambil data ke - 843
# Sukses ambil data ke - 844
# Sukses ambil data ke - 845
# Sukses ambil data ke - 846
# Sukses ambil data ke - 847
# Sukses ambil data ke - 848
# Sukses ambil data ke - 849
# Sukses ambil data ke - 850
# Sukses ambil data ke - 851
# Sukses ambil data ke - 852
# Sukses ambil data ke - 853
# Sukses ambil data ke - 854
# Sukses ambil data ke - 855
# Sukses ambil data ke - 856
# Sukses ambil data ke - 857
# Sukses ambil data ke - 858
# Sukses ambil data ke - 859
# Sukses ambil data ke - 860
# Sukses ambil data ke - 861
# Sukses ambil data ke - 862
# Sukses ambil data ke - 863
# Sukses ambil data ke - 864
# Sukses ambil data ke - 865
# Sukses ambil data ke - 866
# Sukses ambil data ke - 867
# Sukses ambil data ke - 868
# Sukses ambil data ke - 869
# Sukses ambil data ke - 870
# Sukses ambil data ke - 871
# Sukses ambil data ke - 872
# Sukses ambil data ke - 873
# Sukses ambil data ke - 874
# Sukses ambil data ke - 875
# Sukses ambil data ke - 876
# Sukses ambil data ke - 877
# Sukses ambil data ke - 878
# Sukses ambil data ke - 879
# Sukses ambil data ke - 880
# Sukses ambil data ke - 881
# Sukses ambil data ke - 882
# Sukses ambil data ke - 883
# Sukses ambil data ke - 884
# Sukses ambil data ke - 885
# Sukses ambil data ke - 886
# Sukses ambil data ke - 887
# Sukses ambil data ke - 888
# Sukses ambil data ke - 889
# Sukses ambil data ke - 890
# Sukses ambil data ke - 891
# Sukses ambil data ke - 892
# Sukses ambil data ke - 893
# Sukses ambil data ke - 894
# Sukses ambil data ke - 895
# Sukses ambil data ke - 896
# Sukses ambil data ke - 897
# Sukses ambil data ke - 898
# Sukses ambil data ke - 899
# Sukses ambil data ke - 900
# Sukses ambil data ke - 901
# Sukses ambil data ke - 902
# Sukses ambil data ke - 903
# Sukses ambil data ke - 904
# Sukses ambil data ke - 905
# Sukses ambil data ke - 906
# Sukses ambil data ke - 907
# Sukses ambil data ke - 908
# Sukses ambil data ke - 909
# Sukses ambil data ke - 910
# Sukses ambil data ke - 911
# Sukses ambil data ke - 912
# Sukses ambil data ke - 913
# Sukses ambil data ke - 914
# Sukses ambil data ke - 915
# Sukses ambil data ke - 916
# Sukses ambil data ke - 917
# Sukses ambil data ke - 918
# Sukses ambil data ke - 919
# Sukses ambil data ke - 920
# Sukses ambil data ke - 921
# Sukses ambil data ke - 922
# Sukses ambil data ke - 923
# Sukses ambil data ke - 924
# Sukses ambil data ke - 925
# Sukses ambil data ke - 926
# Sukses ambil data ke - 927
# Sukses ambil data ke - 928
# Sukses ambil data ke - 929
# Sukses ambil data ke - 930
# Sukses ambil data ke - 931
# Sukses ambil data ke - 932
# Sukses ambil data ke - 933
# Sukses ambil data ke - 934
# Sukses ambil data ke - 935
# Sukses ambil data ke - 936
# Sukses ambil data ke - 937
# Sukses ambil data ke - 938
# Sukses ambil data ke - 939
# Sukses ambil data ke - 940
# Sukses ambil data ke - 941
# Sukses ambil data ke - 942
# Sukses ambil data ke - 943
# Sukses ambil data ke - 944
# Sukses ambil data ke - 945
# Sukses ambil data ke - 946
# Sukses ambil data ke - 947
# Sukses ambil data ke - 948
# Sukses ambil data ke - 949
# Sukses ambil data ke - 950
# Sukses ambil data ke - 951
# Sukses ambil data ke - 952
# Sukses ambil data ke - 953
# Sukses ambil data ke - 954
# Sukses ambil data ke - 955
# Sukses ambil data ke - 956
# Sukses ambil data ke - 957
# Sukses ambil data ke - 958
# Sukses ambil data ke - 959
# Sukses ambil data ke - 960
# Sukses ambil data ke - 961
# Sukses ambil data ke - 962
# Sukses ambil data ke - 963
# Sukses ambil data ke - 964
# Sukses ambil data ke - 965
# Sukses ambil data ke - 966
# Sukses ambil data ke - 967
# Sukses ambil data ke - 968
# Sukses ambil data ke - 969
# Sukses ambil data ke - 970
# Sukses ambil data ke - 971
# Sukses ambil data ke - 972
# Sukses ambil data ke - 973
# Sukses ambil data ke - 974
# Sukses ambil data ke - 975
# Sukses ambil data ke - 976
# Sukses ambil data ke - 977
# Sukses ambil data ke - 978
# Sukses ambil data ke - 979
# Sukses ambil data ke - 980
# Sukses ambil data ke - 981
# Sukses ambil data ke - 982
# Sukses ambil data ke - 983
# Sukses ambil data ke - 984
# Sukses ambil data ke - 985
# Sukses ambil data ke - 986
# Sukses ambil data ke - 987
# Sukses ambil data ke - 988
# Sukses ambil data ke - 989
# Sukses ambil data ke - 990
# Sukses ambil data ke - 991
# Sukses ambil data ke - 992
# Sukses ambil data ke - 993
# Sukses ambil data ke - 994
# Sukses ambil data ke - 995
# Sukses ambil data ke - 996
# Sukses ambil data ke - 997
# Sukses ambil data ke - 998
# Sukses ambil data ke - 999
# Sukses ambil data ke - 1000
# Sukses ambil data ke - 1001
# Sukses ambil data ke - 1002
# Sukses ambil data ke - 1003
# Sukses ambil data ke - 1004
# Sukses ambil data ke - 1005
# Sukses ambil data ke - 1006
# Sukses ambil data ke - 1007
# Sukses ambil data ke - 1008
# Sukses ambil data ke - 1009
# Sukses ambil data ke - 1010
# Sukses ambil data ke - 1011
# Sukses ambil data ke - 1012
# Sukses ambil data ke - 1013
# Sukses ambil data ke - 1014
# Sukses ambil data ke - 1015
# Sukses ambil data ke - 1016
# Sukses ambil data ke - 1017
# Sukses ambil data ke - 1018
# Sukses ambil data ke - 1019
# Sukses ambil data ke - 1020
# Sukses ambil data ke - 1021
# Sukses ambil data ke - 1022
# Sukses ambil data ke - 1023
# Sukses ambil data ke - 1024
# Sukses ambil data ke - 1025
# Sukses ambil data ke - 1026
# Sukses ambil data ke - 1027
# Sukses ambil data ke - 1028
# Sukses ambil data ke - 1029
# Sukses ambil data ke - 1030
# Sukses ambil data ke - 1031
# Sukses ambil data ke - 1032
# Sukses ambil data ke - 1033
# Sukses ambil data ke - 1034
# Sukses ambil data ke - 1035
# Sukses ambil data ke - 1036
# Sukses ambil data ke - 1037
# Sukses ambil data ke - 1038
# Sukses ambil data ke - 1039
# Sukses ambil data ke - 1040
# Sukses ambil data ke - 1041
# Sukses ambil data ke - 1042
# Sukses ambil data ke - 1043
# Sukses ambil data ke - 1044
# Sukses ambil data ke - 1045
# Sukses ambil data ke - 1046
# Sukses ambil data ke - 1047
# Sukses ambil data ke - 1048
# Sukses ambil data ke - 1049
# Sukses ambil data ke - 1050
# Sukses ambil data ke - 1051
# Sukses ambil data ke - 1052
# Sukses ambil data ke - 1053
# Sukses ambil data ke - 1054
# Sukses ambil data ke - 1055
# Sukses ambil data ke - 1056
# Sukses ambil data ke - 1057
# Sukses ambil data ke - 1058
# Sukses ambil data ke - 1059
# Sukses ambil data ke - 1060
# Sukses ambil data ke - 1061
# Sukses ambil data ke - 1062
# Sukses ambil data ke - 1063
# Sukses ambil data ke - 1064
# Sukses ambil data ke - 1065
# Sukses ambil data ke - 1066
# Sukses ambil data ke - 1067
# Sukses ambil data ke - 1068
# Sukses ambil data ke - 1069
# Sukses ambil data ke - 1070
# Sukses ambil data ke - 1071
# Sukses ambil data ke - 1072
# Sukses ambil data ke - 1073
# Sukses ambil data ke - 1074
# Sukses ambil data ke - 1075
# Sukses ambil data ke - 1076
# Sukses ambil data ke - 1077
# Sukses ambil data ke - 1078
# Sukses ambil data ke - 1079
# Sukses ambil data ke - 1080
# Sukses ambil data ke - 1081
# Sukses ambil data ke - 1082
# Sukses ambil data ke - 1083
# Sukses ambil data ke - 1084
# Sukses ambil data ke - 1085
# Sukses ambil data ke - 1086
# Sukses ambil data ke - 1087
# Sukses ambil data ke - 1088
# Sukses ambil data ke - 1089
# Sukses ambil data ke - 1090
# Sukses ambil data ke - 1091
# Sukses ambil data ke - 1092
# Sukses ambil data ke - 1093
# Sukses ambil data ke - 1094
# Sukses ambil data ke - 1095
# Sukses ambil data ke - 1096
# Sukses ambil data ke - 1097
# Sukses ambil data ke - 1098
# Sukses ambil data ke - 1099
# Sukses ambil data ke - 1100
# Sukses ambil data ke - 1101
# Sukses ambil data ke - 1102
# Sukses ambil data ke - 1103
# Sukses ambil data ke - 1104
# Sukses ambil data ke - 1105
# Sukses ambil data ke - 1106
# Sukses ambil data ke - 1107
# Sukses ambil data ke - 1108
# Sukses ambil data ke - 1109
# Sukses ambil data ke - 1110
# Sukses ambil data ke - 1111
# Sukses ambil data ke - 1112
# Sukses ambil data ke - 1113
# Sukses ambil data ke - 1114
# Sukses ambil data ke - 1115
# Sukses ambil data ke - 1116
# Sukses ambil data ke - 1117
# Sukses ambil data ke - 1118
# Sukses ambil data ke - 1119
# Sukses ambil data ke - 1120
# Sukses ambil data ke - 1121
# Sukses ambil data ke - 1122
# Sukses ambil data ke - 1123
# Sukses ambil data ke - 1124
# Sukses ambil data ke - 1125
# Sukses ambil data ke - 1126
# Sukses ambil data ke - 1127
# Sukses ambil data ke - 1128
# Sukses ambil data ke - 1129
# Sukses ambil data ke - 1130
# Sukses ambil data ke - 1131
# Sukses ambil data ke - 1132
# Sukses ambil data ke - 1133
# Sukses ambil data ke - 1134
# Sukses ambil data ke - 1135
# Sukses ambil data ke - 1136
# Sukses ambil data ke - 1137
# Sukses ambil data ke - 1138
# Sukses ambil data ke - 1139
# Sukses ambil data ke - 1140
# Sukses ambil data ke - 1141
# Sukses ambil data ke - 1142
# Sukses ambil data ke - 1143
# Sukses ambil data ke - 1144
# Sukses ambil data ke - 1145
# Sukses ambil data ke - 1146
# Sukses ambil data ke - 1147
# Sukses ambil data ke - 1148
# Sukses ambil data ke - 1149
# Sukses ambil data ke - 1150
# Sukses ambil data ke - 1151
# Sukses ambil data ke - 1152
# Sukses ambil data ke - 1153
# Sukses ambil data ke - 1154
# Sukses ambil data ke - 1155
# Sukses ambil data ke - 1156
# Sukses ambil data ke - 1157
# Sukses ambil data ke - 1158
# Sukses ambil data ke - 1159
# Sukses ambil data ke - 1160
# Sukses ambil data ke - 1161
# Sukses ambil data ke - 1162
# Sukses ambil data ke - 1163
# Sukses ambil data ke - 1164
# Sukses ambil data ke - 1165
# Sukses ambil data ke - 1166
# Sukses ambil data ke - 1167
# Sukses ambil data ke - 1168
# Sukses ambil data ke - 1169
# Sukses ambil data ke - 1170
# Sukses ambil data ke - 1171
# Sukses ambil data ke - 1172
# Sukses ambil data ke - 1173
# Sukses ambil data ke - 1174
# Sukses ambil data ke - 1175
# Sukses ambil data ke - 1176
# Sukses ambil data ke - 1177
# Sukses ambil data ke - 1178
# Sukses ambil data ke - 1179
# Sukses ambil data ke - 1180
# Sukses ambil data ke - 1181
# Sukses ambil data ke - 1182
# Sukses ambil data ke - 1183
# Sukses ambil data ke - 1184
# Sukses ambil data ke - 1185
# Sukses ambil data ke - 1186
# Sukses ambil data ke - 1187
# Sukses ambil data ke - 1188
# Sukses ambil data ke - 1189
# Sukses ambil data ke - 1190
# Sukses ambil data ke - 1191
# Sukses ambil data ke - 1192
# Sukses ambil data ke - 1193
# Sukses ambil data ke - 1194
# Sukses ambil data ke - 1195
# Sukses ambil data ke - 1196
# Sukses ambil data ke - 1197
# Sukses ambil data ke - 1198
# Sukses ambil data ke - 1199
# Sukses ambil data ke - 1200
# Sukses ambil data ke - 1201
# Sukses ambil data ke - 1202
# Sukses ambil data ke - 1203
# Sukses ambil data ke - 1204
# Sukses ambil data ke - 1205
# Sukses ambil data ke - 1206
# Sukses ambil data ke - 1207
# Sukses ambil data ke - 1208
# Sukses ambil data ke - 1209
# Sukses ambil data ke - 1210
# Sukses ambil data ke - 1211
# Sukses ambil data ke - 1212
# Sukses ambil data ke - 1213
# Sukses ambil data ke - 1214
# Sukses ambil data ke - 1215
# Sukses ambil data ke - 1216
# Sukses ambil data ke - 1217
# Sukses ambil data ke - 1218
# Sukses ambil data ke - 1219
# Sukses ambil data ke - 1220
# Sukses ambil data ke - 1221
# Sukses ambil data ke - 1222
# Sukses ambil data ke - 1223
# Sukses ambil data ke - 1224
# Sukses ambil data ke - 1225
# Sukses ambil data ke - 1226
# Sukses ambil data ke - 1227
# Sukses ambil data ke - 1228
# Sukses ambil data ke - 1229
# Sukses ambil data ke - 1230
# Sukses ambil data ke - 1231
# Sukses ambil data ke - 1232
# Sukses ambil data ke - 1233
# Sukses ambil data ke - 1234
# Sukses ambil data ke - 1235
# Sukses ambil data ke - 1236
# Sukses ambil data ke - 1237
# Sukses ambil data ke - 1238
# Sukses ambil data ke - 1239
# Sukses ambil data ke - 1240
# Sukses ambil data ke - 1241
# Sukses ambil data ke - 1242
# Sukses ambil data ke - 1243
# Sukses ambil data ke - 1244
# Sukses ambil data ke - 1245
# Sukses ambil data ke - 1246
# Sukses ambil data ke - 1247
# Sukses ambil data ke - 1248
# Sukses ambil data ke - 1249
# Sukses ambil data ke - 1250
# Sukses ambil data ke - 1251
# Sukses ambil data ke - 1252
# Sukses ambil data ke - 1253
# Sukses ambil data ke - 1254
# Sukses ambil data ke - 1255
# Sukses ambil data ke - 1256
# Sukses ambil data ke - 1257
# Sukses ambil data ke - 1258
# Sukses ambil data ke - 1259
# Sukses ambil data ke - 1260
# Sukses ambil data ke - 1261
# Sukses ambil data ke - 1262
# Sukses ambil data ke - 1263
# Sukses ambil data ke - 1264
# Sukses ambil data ke - 1265
# Sukses ambil data ke - 1266
# Sukses ambil data ke - 1267
# Sukses ambil data ke - 1268
# Sukses ambil data ke - 1269
# Sukses ambil data ke - 1270
# Sukses ambil data ke - 1271
# Sukses ambil data ke - 1272
# Sukses ambil data ke - 1273
# Sukses ambil data ke - 1274
# Sukses ambil data ke - 1275
# Sukses ambil data ke - 1276
# Sukses ambil data ke - 1277
# Sukses ambil data ke - 1278
# Sukses ambil data ke - 1279
# Sukses ambil data ke - 1280
# Sukses ambil data ke - 1281
# Sukses ambil data ke - 1282
# Sukses ambil data ke - 1283
# Sukses ambil data ke - 1284
# Sukses ambil data ke - 1285
# Sukses ambil data ke - 1286
# Sukses ambil data ke - 1287
# Sukses ambil data ke - 1288
# Sukses ambil data ke - 1289
# Sukses ambil data ke - 1290
# Sukses ambil data ke - 1291
# Sukses ambil data ke - 1292
# Sukses ambil data ke - 1293
# Sukses ambil data ke - 1294
# Sukses ambil data ke - 1295
# Sukses ambil data ke - 1296
# Sukses ambil data ke - 1297
# Sukses ambil data ke - 1298
# Sukses ambil data ke - 1299
# Sukses ambil data ke - 1300
# Sukses ambil data ke - 1301
# Sukses ambil data ke - 1302
# Sukses ambil data ke - 1303
# Sukses ambil data ke - 1304
# Sukses ambil data ke - 1305
# Sukses ambil data ke - 1306
# Sukses ambil data ke - 1307
# Sukses ambil data ke - 1308
# Sukses ambil data ke - 1309
# Sukses ambil data ke - 1310
# Sukses ambil data ke - 1311
# Sukses ambil data ke - 1312
# Sukses ambil data ke - 1313
# Sukses ambil data ke - 1314
# Sukses ambil data ke - 1315
# Sukses ambil data ke - 1316
# Sukses ambil data ke - 1317
# Sukses ambil data ke - 1318
# Sukses ambil data ke - 1319
# Sukses ambil data ke - 1320
# Sukses ambil data ke - 1321
# Sukses ambil data ke - 1322
# Sukses ambil data ke - 1323
# Sukses ambil data ke - 1324
# Sukses ambil data ke - 1325
# Sukses ambil data ke - 1326
# Sukses ambil data ke - 1327
# Sukses ambil data ke - 1328
# Sukses ambil data ke - 1329
# Sukses ambil data ke - 1330
# Sukses ambil data ke - 1331
# Sukses ambil data ke - 1332
# Sukses ambil data ke - 1333
# Sukses ambil data ke - 1334
# Sukses ambil data ke - 1335
# Sukses ambil data ke - 1336
# Sukses ambil data ke - 1337
# Sukses ambil data ke - 1338
# Sukses ambil data ke - 1339
# Sukses ambil data ke - 1340
# Sukses ambil data ke - 1341
# Sukses ambil data ke - 1342
# Sukses ambil data ke - 1343
# Sukses ambil data ke - 1344
# Sukses ambil data ke - 1345
# Sukses ambil data ke - 1346
# Sukses ambil data ke - 1347
# Sukses ambil data ke - 1348
# Sukses ambil data ke - 1349
# Sukses ambil data ke - 1350
# Sukses ambil data ke - 1351
# Sukses ambil data ke - 1352
# Sukses ambil data ke - 1353
# Sukses ambil data ke - 1354
# Sukses ambil data ke - 1355
# Sukses ambil data ke - 1356
# Sukses ambil data ke - 1357
# Sukses ambil data ke - 1358
# Sukses ambil data ke - 1359
# Sukses ambil data ke - 1360
# Sukses ambil data ke - 1361
# Sukses ambil data ke - 1362
# Sukses ambil data ke - 1363
# Sukses ambil data ke - 1364
# Sukses ambil data ke - 1365
# Sukses ambil data ke - 1366
# Sukses ambil data ke - 1367
# Sukses ambil data ke - 1368
# Sukses ambil data ke - 1369
# Sukses ambil data ke - 1370
# Sukses ambil data ke - 1371
# Sukses ambil data ke - 1372
# Sukses ambil data ke - 1373
# Sukses ambil data ke - 1374
# Sukses ambil data ke - 1375
# Sukses ambil data ke - 1376
# Sukses ambil data ke - 1377
# Sukses ambil data ke - 1378
# Sukses ambil data ke - 1379
# Sukses ambil data ke - 1380
# Sukses ambil data ke - 1381
# Sukses ambil data ke - 1382
# Sukses ambil data ke - 1383
# Sukses ambil data ke - 1384
# Sukses ambil data ke - 1385
# Sukses ambil data ke - 1386
# Sukses ambil data ke - 1387
# Sukses ambil data ke - 1388
# Sukses ambil data ke - 1389
# Sukses ambil data ke - 1390
# Sukses ambil data ke - 1391
# Sukses ambil data ke - 1392
# Sukses ambil data ke - 1393
# Sukses ambil data ke - 1394
# Sukses ambil data ke - 1395
# Sukses ambil data ke - 1396
# Sukses ambil data ke - 1397
# Sukses ambil data ke - 1398
# Sukses ambil data ke - 1399
# Sukses ambil data ke - 1400
# Sukses ambil data ke - 1401
# Sukses ambil data ke - 1402
# Sukses ambil data ke - 1403
# Sukses ambil data ke - 1404
# Sukses ambil data ke - 1405
# Sukses ambil data ke - 1406
# Sukses ambil data ke - 1407
# Sukses ambil data ke - 1408
# Sukses ambil data ke - 1409
# Sukses ambil data ke - 1410
# Sukses ambil data ke - 1411
# Sukses ambil data ke - 1412
# Sukses ambil data ke - 1413
# Sukses ambil data ke - 1414
# Sukses ambil data ke - 1415
# Sukses ambil data ke - 1416
# Sukses ambil data ke - 1417
# Sukses ambil data ke - 1418
# Sukses ambil data ke - 1419
# Sukses ambil data ke - 1420
# Sukses ambil data ke - 1421
# Sukses ambil data ke - 1422
# Sukses ambil data ke - 1423
# Sukses ambil data ke - 1424
# Sukses ambil data ke - 1425
# Sukses ambil data ke - 1426
# Sukses ambil data ke - 1427
# Sukses ambil data ke - 1428
# Sukses ambil data ke - 1429
# Sukses ambil data ke - 1430
# Sukses ambil data ke - 1431
# Sukses ambil data ke - 1432
# Sukses ambil data ke - 1433
# Sukses ambil data ke - 1434
# Sukses ambil data ke - 1435
# Sukses ambil data ke - 1436
# Sukses ambil data ke - 1437
# Sukses ambil data ke - 1438
# Sukses ambil data ke - 1439
# Sukses ambil data ke - 1440
# Sukses ambil data ke - 1441
# Sukses ambil data ke - 1442
# Sukses ambil data ke - 1443
# Sukses ambil data ke - 1444
# Sukses ambil data ke - 1445
# Sukses ambil data ke - 1446
# Sukses ambil data ke - 1447
# Sukses ambil data ke - 1448
# Sukses ambil data ke - 1449
# Sukses ambil data ke - 1450
# Sukses ambil data ke - 1451
# Sukses ambil data ke - 1452
# Sukses ambil data ke - 1453
# Sukses ambil data ke - 1454
# Sukses ambil data ke - 1455
# Sukses ambil data ke - 1456
# Sukses ambil data ke - 1457
# Sukses ambil data ke - 1458
# Sukses ambil data ke - 1459
# Sukses ambil data ke - 1460
# Sukses ambil data ke - 1461
# Sukses ambil data ke - 1462
# Sukses ambil data ke - 1463
# Sukses ambil data ke - 1464
# Sukses ambil data ke - 1465
# Sukses ambil data ke - 1466
# Sukses ambil data ke - 1467
# Sukses ambil data ke - 1468
# Sukses ambil data ke - 1469
# Sukses ambil data ke - 1470
# Sukses ambil data ke - 1471
# Sukses ambil data ke - 1472
# Sukses ambil data ke - 1473
# Sukses ambil data ke - 1474
# Sukses ambil data ke - 1475
# Sukses ambil data ke - 1476
# Sukses ambil data ke - 1477
# Sukses ambil data ke - 1478
# Sukses ambil data ke - 1479
# Sukses ambil data ke - 1480
# Sukses ambil data ke - 1481
# Sukses ambil data ke - 1482
# Sukses ambil data ke - 1483
# Sukses ambil data ke - 1484
# Sukses ambil data ke - 1485
# Sukses ambil data ke - 1486
# Sukses ambil data ke - 1487
# Sukses ambil data ke - 1488
# Sukses ambil data ke - 1489
# Sukses ambil data ke - 1490
# Sukses ambil data ke - 1491
# Sukses ambil data ke - 1492
# Sukses ambil data ke - 1493
# Sukses ambil data ke - 1494
# Sukses ambil data ke - 1495
# Sukses ambil data ke - 1496
# Sukses ambil data ke - 1497
# Sukses ambil data ke - 1498
# Sukses ambil data ke - 1499
# Sukses ambil data ke - 1500
# Sukses ambil data ke - 1501
# Sukses ambil data ke - 1502
# Sukses ambil data ke - 1503
# Sukses ambil data ke - 1504
# Sukses ambil data ke - 1505
# Sukses ambil data ke - 1506
# Sukses ambil data ke - 1507
# Sukses ambil data ke - 1508
# Sukses ambil data ke - 1509
# Sukses ambil data ke - 1510
# Sukses ambil data ke - 1511
# Sukses ambil data ke - 1512
# Sukses ambil data ke - 1513
# Sukses ambil data ke - 1514
# Sukses ambil data ke - 1515
# Sukses ambil data ke - 1516
# Sukses ambil data ke - 1517
# Sukses ambil data ke - 1518
# Sukses ambil data ke - 1519
# Sukses ambil data ke - 1520
# Sukses ambil data ke - 1521
# Sukses ambil data ke - 1522
# Sukses ambil data ke - 1523
# Sukses ambil data ke - 1524
# Sukses ambil data ke - 1525
# Sukses ambil data ke - 1526
# Sukses ambil data ke - 1527
# Sukses ambil data ke - 1528
# Sukses ambil data ke - 1529
# Sukses ambil data ke - 1530
# Sukses ambil data ke - 1531
# Sukses ambil data ke - 1532
# Sukses ambil data ke - 1533
# Sukses ambil data ke - 1534
# Sukses ambil data ke - 1535
# Sukses ambil data ke - 1536
# Sukses ambil data ke - 1537
# Sukses ambil data ke - 1538
# Sukses ambil data ke - 1539
# Sukses ambil data ke - 1540
# Sukses ambil data ke - 1541
# Sukses ambil data ke - 1542
# Sukses ambil data ke - 1543
# Sukses ambil data ke - 1544
# Sukses ambil data ke - 1545
# Sukses ambil data ke - 1546
# Sukses ambil data ke - 1547
# Sukses ambil data ke - 1548
# Sukses ambil data ke - 1549
# Sukses ambil data ke - 1550
# Sukses ambil data ke - 1551
# Sukses ambil data ke - 1552
# Sukses ambil data ke - 1553
# Sukses ambil data ke - 1554
# Sukses ambil data ke - 1555
# Sukses ambil data ke - 1556
# Sukses ambil data ke - 1557
# Sukses ambil data ke - 1558
# Sukses ambil data ke - 1559
# Sukses ambil data ke - 1560
# Sukses ambil data ke - 1561
# Sukses ambil data ke - 1562
# Sukses ambil data ke - 1563
# Sukses ambil data ke - 1564
# Sukses ambil data ke - 1565
# Sukses ambil data ke - 1566
# Sukses ambil data ke - 1567
# Sukses ambil data ke - 1568
# Sukses ambil data ke - 1569
# Sukses ambil data ke - 1570
# Sukses ambil data ke - 1571
# Sukses ambil data ke - 1572
# Sukses ambil data ke - 1573
# Sukses ambil data ke - 1574
# Sukses ambil data ke - 1575
# Sukses ambil data ke - 1576
# Sukses ambil data ke - 1577
# Sukses ambil data ke - 1578
# Sukses ambil data ke - 1579
# Sukses ambil data ke - 1580
# Sukses ambil data ke - 1581
# Sukses ambil data ke - 1582
# Sukses ambil data ke - 1583
# Sukses ambil data ke - 1584
# Sukses ambil data ke - 1585
# Sukses ambil data ke - 1586
# Sukses ambil data ke - 1587
# Sukses ambil data ke - 1588
# Sukses ambil data ke - 1589
# Sukses ambil data ke - 1590
# Sukses ambil data ke - 1591
# Sukses ambil data ke - 1592
# Sukses ambil data ke - 1593
# Sukses ambil data ke - 1594
# Sukses ambil data ke - 1595
# Sukses ambil data ke - 1596
# Sukses ambil data ke - 1597
# Sukses ambil data ke - 1598
# Sukses ambil data ke - 1599
# Sukses ambil data ke - 1600
# Sukses ambil data ke - 1601
# Sukses ambil data ke - 1602
# Sukses ambil data ke - 1603
# Sukses ambil data ke - 1604
# Sukses ambil data ke - 1605
# Sukses ambil data ke - 1606
# Sukses ambil data ke - 1607
# Sukses ambil data ke - 1608
# Sukses ambil data ke - 1609
# Sukses ambil data ke - 1610
# Sukses ambil data ke - 1611
# Sukses ambil data ke - 1612
# Sukses ambil data ke - 1613
# Sukses ambil data ke - 1614
# Sukses ambil data ke - 1615
# Sukses ambil data ke - 1616
# Sukses ambil data ke - 1617
# Sukses ambil data ke - 1618
# Sukses ambil data ke - 1619
# Sukses ambil data ke - 1620
# Sukses ambil data ke - 1621
# Sukses ambil data ke - 1622
# Sukses ambil data ke - 1623
# Sukses ambil data ke - 1624
# Sukses ambil data ke - 1625
# Sukses ambil data ke - 1626
# Sukses ambil data ke - 1627
# Sukses ambil data ke - 1628
# Sukses ambil data ke - 1629
# Sukses ambil data ke - 1630
# Sukses ambil data ke - 1631
# Sukses ambil data ke - 1632
# Sukses ambil data ke - 1633
# Sukses ambil data ke - 1634
# Sukses ambil data ke - 1635
# Sukses ambil data ke - 1636
# Sukses ambil data ke - 1637
# Sukses ambil data ke - 1638
# Sukses ambil data ke - 1639
# Sukses ambil data ke - 1640
# Sukses ambil data ke - 1641
# Sukses ambil data ke - 1642
# Sukses ambil data ke - 1643
# Sukses ambil data ke - 1644
# Sukses ambil data ke - 1645
# Sukses ambil data ke - 1646
# Sukses ambil data ke - 1647
# Sukses ambil data ke - 1648
# Sukses ambil data ke - 1649
# Sukses ambil data ke - 1650
# Sukses ambil data ke - 1651
# Sukses ambil data ke - 1652
# Sukses ambil data ke - 1653
# Sukses ambil data ke - 1654
# Sukses ambil data ke - 1655
# Sukses ambil data ke - 1656
# Sukses ambil data ke - 1657
# Sukses ambil data ke - 1658
# Sukses ambil data ke - 1659
# Sukses ambil data ke - 1660
# Sukses ambil data ke - 1661
# Sukses ambil data ke - 1662
# Sukses ambil data ke - 1663
# Sukses ambil data ke - 1664
# Sukses ambil data ke - 1665
# Sukses ambil data ke - 1666
# Sukses ambil data ke - 1667
# Sukses ambil data ke - 1668
# Sukses ambil data ke - 1669
# Sukses ambil data ke - 1670
# Sukses ambil data ke - 1671
# Sukses ambil data ke - 1672
# Sukses ambil data ke - 1673
# Sukses ambil data ke - 1674
# Sukses ambil data ke - 1675
# Sukses ambil data ke - 1676
# Sukses ambil data ke - 1677
# Sukses ambil data ke - 1678
# Sukses ambil data ke - 1679
# Sukses ambil data ke - 1680
# Sukses ambil data ke - 1681
# Sukses ambil data ke - 1682
# Sukses ambil data ke - 1683
# Sukses ambil data ke - 1684
# Sukses ambil data ke - 1685
# Sukses ambil data ke - 1686
# Sukses ambil data ke - 1687
# Sukses ambil data ke - 1688
# Sukses ambil data ke - 1689
# Sukses ambil data ke - 1690
# Sukses ambil data ke - 1691
# Sukses ambil data ke - 1692
# Sukses ambil data ke - 1693
# Sukses ambil data ke - 1694
# Sukses ambil data ke - 1695
# Sukses ambil data ke - 1696
# Sukses ambil data ke - 1697
# Sukses ambil data ke - 1698
# Sukses ambil data ke - 1699
# Sukses ambil data ke - 1700
# Sukses ambil data ke - 1701
# Sukses ambil data ke - 1702
# Sukses ambil data ke - 1703
# Sukses ambil data ke - 1704
# Sukses ambil data ke - 1705
# Sukses ambil data ke - 1706
# Sukses ambil data ke - 1707
# Sukses ambil data ke - 1708
# Sukses ambil data ke - 1709
# Sukses ambil data ke - 1710
# Sukses ambil data ke - 1711
# Sukses ambil data ke - 1712
# Sukses ambil data ke - 1713
# Sukses ambil data ke - 1714
# Sukses ambil data ke - 1715
# Sukses ambil data ke - 1716
# Sukses ambil data ke - 1717
# Sukses ambil data ke - 1718
# Sukses ambil data ke - 1719
# Sukses ambil data ke - 1720
# Sukses ambil data ke - 1721
# Sukses ambil data ke - 1722
# Sukses ambil data ke - 1723
# Sukses ambil data ke - 1724
# Sukses ambil data ke - 1725
# Sukses ambil data ke - 1726
# Sukses ambil data ke - 1727
# Sukses ambil data ke - 1728
# Sukses ambil data ke - 1729
# Sukses ambil data ke - 1730
# Sukses ambil data ke - 1731
# Sukses ambil data ke - 1732
# Sukses ambil data ke - 1733
# Sukses ambil data ke - 1734
# Sukses ambil data ke - 1735
# Sukses ambil data ke - 1736
# Sukses ambil data ke - 1737
# Sukses ambil data ke - 1738
# Sukses ambil data ke - 1739
# Sukses ambil data ke - 1740
# Sukses ambil data ke - 1741
# Sukses ambil data ke - 1742
# Sukses ambil data ke - 1743
# Sukses ambil data ke - 1744
# Sukses ambil data ke - 1745
# Sukses ambil data ke - 1746
# Sukses ambil data ke - 1747
# Sukses ambil data ke - 1748
# Sukses ambil data ke - 1749
# Sukses ambil data ke - 1750
# Sukses ambil data ke - 1751
# Sukses ambil data ke - 1752
# ...
# Sukses ambil data ke - 9430
# Sukses ambil data ke - 9431
# Sukses ambil data ke - 9432
# Sukses ambil data ke - 9433
# Sukses ambil data ke - 9434
# Sukses ambil data ke - 9435
# Sukses ambil data ke - 9436
# Sukses ambil data ke - 9437
# Sukses ambil data ke - 9438
# Sukses ambil data ke - 9439
# Sukses ambil data ke - 9440
# Sukses ambil data ke - 9441
# Sukses ambil data ke - 9442
# Sukses ambil data ke - 9443
# Sukses ambil data ke - 9444
# Sukses ambil data ke - 9445
# Sukses ambil data ke - 9446
# Sukses ambil data ke - 9447
# Sukses ambil data ke - 9448
# Sukses ambil data ke - 9449
# Sukses ambil data ke - 9450
# Sukses ambil data ke - 9451
# Sukses ambil data ke - 9452
# Sukses ambil data ke - 9453
# Sukses ambil data ke - 9454
# Sukses ambil data ke - 9455
# Sukses ambil data ke - 9456
# Sukses ambil data ke - 9457
# Sukses ambil data ke - 9458
# Sukses ambil data ke - 9459
# Sukses ambil data ke - 9460
# Sukses ambil data ke - 9461
# Sukses ambil data ke - 9462
# Sukses ambil data ke - 9463
# Sukses ambil data ke - 9464
# Sukses ambil data ke - 9465
# Sukses ambil data ke - 9466
# Sukses ambil data ke - 9467
# Sukses ambil data ke - 9468
# Sukses ambil data ke - 9469
# Sukses ambil data ke - 9470
# Sukses ambil data ke - 9471
# Sukses ambil data ke - 9472
# Sukses ambil data ke - 9473
# Sukses ambil data ke - 9474
# Sukses ambil data ke - 9475
# Sukses ambil data ke - 9476
# Sukses ambil data ke - 9477
# Sukses ambil data ke - 9478
# Sukses ambil data ke - 9479
# Sukses ambil data ke - 9480
# Sukses ambil data ke - 9481
# Sukses ambil data ke - 9482
# Sukses ambil data ke - 9483
# Sukses ambil data ke - 9484
# Sukses ambil data ke - 9485
# Sukses ambil data ke - 9486
# Sukses ambil data ke - 9487
# Sukses ambil data ke - 9488
# Sukses ambil data ke - 9489
# Sukses ambil data ke - 9490
# Sukses ambil data ke - 9491
# Sukses ambil data ke - 9492
# Sukses ambil data ke - 9493
# Sukses ambil data ke - 9494
# Sukses ambil data ke - 9495
# Sukses ambil data ke - 9496
# Sukses ambil data ke - 9497
# Sukses ambil data ke - 9498
# Sukses ambil data ke - 9499
# Sukses ambil data ke - 9500
# Sukses ambil data ke - 9501
# Sukses ambil data ke - 9502
# Sukses ambil data ke - 9503
# Sukses ambil data ke - 9504
# Sukses ambil data ke - 9505
# Sukses ambil data ke - 9506
# Sukses ambil data ke - 9507
# Sukses ambil data ke - 9508
# Sukses ambil data ke - 9509
# Sukses ambil data ke - 9510
# Sukses ambil data ke - 9511
# Sukses ambil data ke - 9512
# Sukses ambil data ke - 9513
# Sukses ambil data ke - 9514
# Sukses ambil data ke - 9515
# Sukses ambil data ke - 9516
# Sukses ambil data ke - 9517
# Sukses ambil data ke - 9518
# Sukses ambil data ke - 9519
# Sukses ambil data ke - 9520
# Sukses ambil data ke - 9521
# Sukses ambil data ke - 9522
# Sukses ambil data ke - 9523
# Sukses ambil data ke - 9524
# Sukses ambil data ke - 9525
# Sukses ambil data ke - 9526
# Sukses ambil data ke - 9527
# Sukses ambil data ke - 9528
# Sukses ambil data ke - 9529
# Sukses ambil data ke - 9530
# Sukses ambil data ke - 9531
# Sukses ambil data ke - 9532
# Sukses ambil data ke - 9533
# Sukses ambil data ke - 9534
# Sukses ambil data ke - 9535
# Sukses ambil data ke - 9536
# Sukses ambil data ke - 9537
# Sukses ambil data ke - 9538
# Sukses ambil data ke - 9539
# Sukses ambil data ke - 9540
# Sukses ambil data ke - 9541
# Sukses ambil data ke - 9542
# Sukses ambil data ke - 9543
# Sukses ambil data ke - 9544
# Sukses ambil data ke - 9545
# Sukses ambil data ke - 9546
# Sukses ambil data ke - 9547
# Sukses ambil data ke - 9548
# Sukses ambil data ke - 9549
# Sukses ambil data ke - 9550
# Sukses ambil data ke - 9551
# Sukses ambil data ke - 9552
# Sukses ambil data ke - 9553
# Sukses ambil data ke - 9554
# Sukses ambil data ke - 9555
# Sukses ambil data ke - 9556
# Sukses ambil data ke - 9557
# Sukses ambil data ke - 9558
# Sukses ambil data ke - 9559
# Sukses ambil data ke - 9560
# Sukses ambil data ke - 9561
# Sukses ambil data ke - 9562
# Sukses ambil data ke - 9563
# Sukses ambil data ke - 9564
# Sukses ambil data ke - 9565
# Sukses ambil data ke - 9566
# Sukses ambil data ke - 9567
# Sukses ambil data ke - 9568
# Sukses ambil data ke - 9569
# Sukses ambil data ke - 9570
# Sukses ambil data ke - 9571
# Sukses ambil data ke - 9572
# Sukses ambil data ke - 9573
# Sukses ambil data ke - 9574
# Sukses ambil data ke - 9575
# Sukses ambil data ke - 9576
# Sukses ambil data ke - 9577
# Sukses ambil data ke - 9578
# Sukses ambil data ke - 9579
# Sukses ambil data ke - 9580
# Sukses ambil data ke - 9581
# Sukses ambil data ke - 9582
# Sukses ambil data ke - 9583
# Sukses ambil data ke - 9584
# Sukses ambil data ke - 9585
# Sukses ambil data ke - 9586
# Sukses ambil data ke - 9587
# Sukses ambil data ke - 9588
# Sukses ambil data ke - 9589
# Sukses ambil data ke - 9590
# Sukses ambil data ke - 9591
# Sukses ambil data ke - 9592
# Sukses ambil data ke - 9593
# Sukses ambil data ke - 9594
# Sukses ambil data ke - 9595
# Sukses ambil data ke - 9596
# Sukses ambil data ke - 9597
# Sukses ambil data ke - 9598
# Sukses ambil data ke - 9599
# Sukses ambil data ke - 9600
# Sukses ambil data ke - 9601
# Sukses ambil data ke - 9602
# Sukses ambil data ke - 9603
# Sukses ambil data ke - 9604
# Sukses ambil data ke - 9605
# Sukses ambil data ke - 9606
# Sukses ambil data ke - 9607
# Sukses ambil data ke - 9608
# Sukses ambil data ke - 9609
# Sukses ambil data ke - 9610
# Sukses ambil data ke - 9611
# Sukses ambil data ke - 9612
# Sukses ambil data ke - 9613
# Sukses ambil data ke - 9614
# Sukses ambil data ke - 9615
# Sukses ambil data ke - 9616
# Sukses ambil data ke - 9617
# Sukses ambil data ke - 9618
# Sukses ambil data ke - 9619
# Sukses ambil data ke - 9620
# Sukses ambil data ke - 9621
# Sukses ambil data ke - 9622
# Sukses ambil data ke - 9623
# Sukses ambil data ke - 9624
# Sukses ambil data ke - 9625
# Sukses ambil data ke - 9626
# Sukses ambil data ke - 9627
# Sukses ambil data ke - 9628
# Sukses ambil data ke - 9629
# Sukses ambil data ke - 9630
# Sukses ambil data ke - 9631
# Sukses ambil data ke - 9632
# Sukses ambil data ke - 9633
# Sukses ambil data ke - 9634
# Sukses ambil data ke - 9635
# Sukses ambil data ke - 9636
# Sukses ambil data ke - 9637
# Sukses ambil data ke - 9638
# Sukses ambil data ke - 9639
# Sukses ambil data ke - 9640
# Sukses ambil data ke - 9641
# Sukses ambil data ke - 9642
# Sukses ambil data ke - 9643
# Sukses ambil data ke - 9644
# Sukses ambil data ke - 9645
# Sukses ambil data ke - 9646
# Sukses ambil data ke - 9647
# Sukses ambil data ke - 9648
# Sukses ambil data ke - 9649
# Sukses ambil data ke - 9650
# Sukses ambil data ke - 9651
# Sukses ambil data ke - 9652
# Sukses ambil data ke - 9653
# Sukses ambil data ke - 9654
# Sukses ambil data ke - 9655
# Sukses ambil data ke - 9656
# Sukses ambil data ke - 9657
# Sukses ambil data ke - 9658
# Sukses ambil data ke - 9659
# Sukses ambil data ke - 9660
# Sukses ambil data ke - 9661
# Sukses ambil data ke - 9662
# Sukses ambil data ke - 9663
# Sukses ambil data ke - 9664
# Sukses ambil data ke - 9665
# Sukses ambil data ke - 9666
# Sukses ambil data ke - 9667
# Sukses ambil data ke - 9668
# Sukses ambil data ke - 9669
# Sukses ambil data ke - 9670
# Sukses ambil data ke - 9671
# Sukses ambil data ke - 9672
# Sukses ambil data ke - 9673
# Sukses ambil data ke - 9674
# Sukses ambil data ke - 9675
# Sukses ambil data ke - 9676
# Sukses ambil data ke - 9677
# Sukses ambil data ke - 9678
# Sukses ambil data ke - 9679
# Sukses ambil data ke - 9680
# Sukses ambil data ke - 9681
# Sukses ambil data ke - 9682
# Sukses ambil data ke - 9683
# Sukses ambil data ke - 9684
# Sukses ambil data ke - 9685
# Sukses ambil data ke - 9686
# Sukses ambil data ke - 9687
# Sukses ambil data ke - 9688
# Sukses ambil data ke - 9689
# Sukses ambil data ke - 9690
# Sukses ambil data ke - 9691
# Sukses ambil data ke - 9692
# Sukses ambil data ke - 9693
# Sukses ambil data ke - 9694
# Sukses ambil data ke - 9695
# Sukses ambil data ke - 9696
# Sukses ambil data ke - 9697
# Sukses ambil data ke - 9698
# Sukses ambil data ke - 9699
# Sukses ambil data ke - 9700
# Sukses ambil data ke - 9701
# Sukses ambil data ke - 9702
# Sukses ambil data ke - 9703
# Sukses ambil data ke - 9704
# Sukses ambil data ke - 9705
# Sukses ambil data ke - 9706
# Sukses ambil data ke - 9707
# Sukses ambil data ke - 9708
# Sukses ambil data ke - 9709
# Sukses ambil data ke - 9710
# Sukses ambil data ke - 9711
# Sukses ambil data ke - 9712
# Sukses ambil data ke - 9713
# Sukses ambil data ke - 9714
# Sukses ambil data ke - 9715
# Sukses ambil data ke - 9716
# Sukses ambil data ke - 9717
# Sukses ambil data ke - 9718
# Sukses ambil data ke - 9719
# Sukses ambil data ke - 9720
# Sukses ambil data ke - 9721
# Sukses ambil data ke - 9722
# Sukses ambil data ke - 9723
# Sukses ambil data ke - 9724
# Sukses ambil data ke - 9725
# Sukses ambil data ke - 9726
# Sukses ambil data ke - 9727
# Sukses ambil data ke - 9728
# Sukses ambil data ke - 9729
# Sukses ambil data ke - 9730
# Sukses ambil data ke - 9731
# Sukses ambil data ke - 9732
# Sukses ambil data ke - 9733
# Sukses ambil data ke - 9734
# Sukses ambil data ke - 9735
# Sukses ambil data ke - 9736
# Sukses ambil data ke - 9737
# Sukses ambil data ke - 9738
# Sukses ambil data ke - 9739
# Sukses ambil data ke - 9740
# Sukses ambil data ke - 9741
# Sukses ambil data ke - 9742
# Sukses ambil data ke - 9743
# Sukses ambil data ke - 9744
# Sukses ambil data ke - 9745
# Sukses ambil data ke - 9746
# Sukses ambil data ke - 9747
# Sukses ambil data ke - 9748
# Sukses ambil data ke - 9749
# Sukses ambil data ke - 9750
# Sukses ambil data ke - 9751
# Sukses ambil data ke - 9752
# Sukses ambil data ke - 9753
# Sukses ambil data ke - 9754
# Sukses ambil data ke - 9755
# Sukses ambil data ke - 9756
# Sukses ambil data ke - 9757
# Sukses ambil data ke - 9758
# Sukses ambil data ke - 9759
# Sukses ambil data ke - 9760
# Sukses ambil data ke - 9761
# Sukses ambil data ke - 9762
# Sukses ambil data ke - 9763
# Sukses ambil data ke - 9764
# Sukses ambil data ke - 9765
# Sukses ambil data ke - 9766
# Sukses ambil data ke - 9767
# Sukses ambil data ke - 9768
# Sukses ambil data ke - 9769
# Sukses ambil data ke - 9770
# Sukses ambil data ke - 9771
# Sukses ambil data ke - 9772
# Sukses ambil data ke - 9773
# Sukses ambil data ke - 9774
# Sukses ambil data ke - 9775
# Sukses ambil data ke - 9776
# Sukses ambil data ke - 9777
# Sukses ambil data ke - 9778
# Sukses ambil data ke - 9779
# Sukses ambil data ke - 9780
# Sukses ambil data ke - 9781
# Sukses ambil data ke - 9782
# Sukses ambil data ke - 9783
# Sukses ambil data ke - 9784
# Sukses ambil data ke - 9785
# Sukses ambil data ke - 9786
# Sukses ambil data ke - 9787
# Sukses ambil data ke - 9788
# Sukses ambil data ke - 9789
# Sukses ambil data ke - 9790
# Sukses ambil data ke - 9791
# Sukses ambil data ke - 9792
# Sukses ambil data ke - 9793
# Sukses ambil data ke - 9794
# Sukses ambil data ke - 9795
# Sukses ambil data ke - 9796
# Sukses ambil data ke - 9797
# Sukses ambil data ke - 9798
# Sukses ambil data ke - 9799
# Sukses ambil data ke - 9800
# Sukses ambil data ke - 9801
# Sukses ambil data ke - 9802
# Sukses ambil data ke - 9803
# Sukses ambil data ke - 9804
# Sukses ambil data ke - 9805
# Sukses ambil data ke - 9806
# Sukses ambil data ke - 9807
# Sukses ambil data ke - 9808
# Sukses ambil data ke - 9809
# Sukses ambil data ke - 9810
# Sukses ambil data ke - 9811
# Sukses ambil data ke - 9812
# Sukses ambil data ke - 9813
# Sukses ambil data ke - 9814
# Sukses ambil data ke - 9815
# Sukses ambil data ke - 9816
# Sukses ambil data ke - 9817
# Sukses ambil data ke - 9818
# Sukses ambil data ke - 9819
# Sukses ambil data ke - 9820
# Sukses ambil data ke - 9821
# Sukses ambil data ke - 9822
# Sukses ambil data ke - 9823
# Sukses ambil data ke - 9824
# Sukses ambil data ke - 9825
# Sukses ambil data ke - 9826
# Sukses ambil data ke - 9827
# Sukses ambil data ke - 9828
# Sukses ambil data ke - 9829
# Sukses ambil data ke - 9830
# Sukses ambil data ke - 9831
# Sukses ambil data ke - 9832
# Sukses ambil data ke - 9833
# Sukses ambil data ke - 9834
# Sukses ambil data ke - 9835
# Sukses ambil data ke - 9836
# Sukses ambil data ke - 9837
# Sukses ambil data ke - 9838
# Sukses ambil data ke - 9839
# Sukses ambil data ke - 9840
# Sukses ambil data ke - 9841
# Sukses ambil data ke - 9842
# Sukses ambil data ke - 9843
# Sukses ambil data ke - 9844
# Sukses ambil data ke - 9845
# Sukses ambil data ke - 9846
# Sukses ambil data ke - 9847
# Sukses ambil data ke - 9848
# Sukses ambil data ke - 9849
# Sukses ambil data ke - 9850
# Sukses ambil data ke - 9851
# Sukses ambil data ke - 9852
# Sukses ambil data ke - 9853
# Sukses ambil data ke - 9854
# Sukses ambil data ke - 9855
# Sukses ambil data ke - 9856
# Sukses ambil data ke - 9857
# Sukses ambil data ke - 9858
# Sukses ambil data ke - 9859
# Sukses ambil data ke - 9860
# Sukses ambil data ke - 9861
# Sukses ambil data ke - 9862
# Sukses ambil data ke - 9863
# Sukses ambil data ke - 9864
# Sukses ambil data ke - 9865
# Sukses ambil data ke - 9866
# Sukses ambil data ke - 9867
# Sukses ambil data ke - 9868
# Sukses ambil data ke - 9869
# Sukses ambil data ke - 9870
# Sukses ambil data ke - 9871
# Sukses ambil data ke - 9872
# Sukses ambil data ke - 9873
# Sukses ambil data ke - 9874
# Sukses ambil data ke - 9875
# Sukses ambil data ke - 9876
# Sukses ambil data ke - 9877
# Sukses ambil data ke - 9878
# Sukses ambil data ke - 9879
# Sukses ambil data ke - 9880
# Sukses ambil data ke - 9881
# Sukses ambil data ke - 9882
# Sukses ambil data ke - 9883
# Sukses ambil data ke - 9884
# Sukses ambil data ke - 9885
# Sukses ambil data ke - 9886
# Sukses ambil data ke - 9887
# Sukses ambil data ke - 9888
# Sukses ambil data ke - 9889
# Sukses ambil data ke - 9890
# Sukses ambil data ke - 9891
# Sukses ambil data ke - 9892
# Sukses ambil data ke - 9893
# Sukses ambil data ke - 9894
# Sukses ambil data ke - 9895
# Sukses ambil data ke - 9896
# Sukses ambil data ke - 9897
# Sukses ambil data ke - 9898
# Sukses ambil data ke - 9899
# Sukses ambil data ke - 9900
# Sukses ambil data ke - 9901
# Sukses ambil data ke - 9902
# Sukses ambil data ke - 9903
# Sukses ambil data ke - 9904
# Sukses ambil data ke - 9905
# Sukses ambil data ke - 9906
# Sukses ambil data ke - 9907
# Sukses ambil data ke - 9908
# Sukses ambil data ke - 9909
# Sukses ambil data ke - 9910
# Sukses ambil data ke - 9911
# Sukses ambil data ke - 9912
# Sukses ambil data ke - 9913
# Sukses ambil data ke - 9914
# Sukses ambil data ke - 9915
# Sukses ambil data ke - 9916
# Sukses ambil data ke - 9917
# Sukses ambil data ke - 9918
# Sukses ambil data ke - 9919
# Sukses ambil data ke - 9920
# Sukses ambil data ke - 9921
# Sukses ambil data ke - 9922
# Sukses ambil data ke - 9923
# Sukses ambil data ke - 9924
# Sukses ambil data ke - 9925
# Sukses ambil data ke - 9926
# Sukses ambil data ke - 9927
# Sukses ambil data ke - 9928
# Sukses ambil data ke - 9929
# Sukses ambil data ke - 9930
# Sukses ambil data ke - 9931
# Sukses ambil data ke - 9932
# Sukses ambil data ke - 9933
# Sukses ambil data ke - 9934
# Sukses ambil data ke - 9935
# Sukses ambil data ke - 9936
# Sukses ambil data ke - 9937
# Sukses ambil data ke - 9938
# Sukses ambil data ke - 9939
# Sukses ambil data ke - 9940
# Sukses ambil data ke - 9941
# Sukses ambil data ke - 9942
# Sukses ambil data ke - 9943
# Sukses ambil data ke - 9944
# Sukses ambil data ke - 9945
# Sukses ambil data ke - 9946
# Sukses ambil data ke - 9947
# Sukses ambil data ke - 9948
# Sukses ambil data ke - 9949
# Sukses ambil data ke - 9950
# Sukses ambil data ke - 9951
# Sukses ambil data ke - 9952
# Sukses ambil data ke - 9953
# Sukses ambil data ke - 9954
# Sukses ambil data ke - 9955
# Sukses ambil data ke - 9956
# Sukses ambil data ke - 9957
# Sukses ambil data ke - 9958
# Sukses ambil data ke - 9959
# Sukses ambil data ke - 9960
# Sukses ambil data ke - 9961
# Sukses ambil data ke - 9962
# Sukses ambil data ke - 9963
# Sukses ambil data ke - 9964
# Sukses ambil data ke - 9965
# Sukses ambil data ke - 9966
# Sukses ambil data ke - 9967
# Sukses ambil data ke - 9968
# Sukses ambil data ke - 9969
# Sukses ambil data ke - 9970
# Sukses ambil data ke - 9971
# Sukses ambil data ke - 9972
# Sukses ambil data ke - 9973
# Sukses ambil data ke - 9974
# Sukses ambil data ke - 9975
# Sukses ambil data ke - 9976
# Sukses ambil data ke - 9977
# Sukses ambil data ke - 9978
# Sukses ambil data ke - 9979
# Sukses ambil data ke - 9980
# Sukses ambil data ke - 9981
# Sukses ambil data ke - 9982
# Sukses ambil data ke - 9983
# Sukses ambil data ke - 9984
# Sukses ambil data ke - 9985
# Sukses ambil data ke - 9986
# Sukses ambil data ke - 9987
# Sukses ambil data ke - 9988
# Sukses ambil data ke - 9989
# Sukses ambil data ke - 9990
# Sukses ambil data ke - 9991
# Sukses ambil data ke - 9992
# Sukses ambil data ke - 9993
# Sukses ambil data ke - 9994
# Sukses ambil data ke - 9995
# Sukses ambil data ke - 9996
# Sukses ambil data ke - 9997
# Sukses ambil data ke - 9998
# Sukses ambil data ke - 9999
# Sukses ambil data ke - 10000

# %% [markdown]
# ## 5. Menyimpan Data ke File CSV
#
# Setelah data terkumpul, kita mengonversinya menjadi DataFrame dan menyimpannya sebagai file CSV.
#
# ### Penjelasan:
# - **`pd.DataFrame(data)`**: Mengubah list `data` menjadi DataFrame.
# - **`to_csv`**: Menyimpan DataFrame ke file `dataset.csv`.
#   - **`index=False`**: Tidak menyertakan indeks baris.
#   - **`encoding='utf-8'`**: Mendukung karakter khusus (misalnya, bahasa Indonesia).
# - **Output**: Menampilkan jumlah data yang diambil dan lokasi file.

# %%
df = pd.DataFrame(data)
df.to_csv("dataset.csv", index=False, encoding="utf-8")
print(f"\nTotal data berhasil diambil: {len(df)}")
print("Data disimpan di: dataset.csv")
# Out:
# Total data berhasil diambil: 10000
# Data disimpan di: dataset.csv

# %% [markdown]
# ## 6. Catatan dan Rekomendasi
#
# ### Catatan Penting:
# - **Batasan Library**: Jumlah ulasan yang dapat diambil mungkin dibatasi oleh `google-play-scraper`. Jika Anda membutuhkan lebih dari 10.000 ulasan, pertimbangkan untuk menjalankan ulang dengan jeda waktu.
# - **Etika Scraping**: Gunakan data hanya untuk tujuan yang sah dan patuhi kebijakan Google Play Store.
# - **Pemecahan Masalah**: Jika terjadi error seperti `NameError`, pastikan sel import library dijalankan terlebih dahulu.
#
# ### Rekomendasi:
# - Tambahkan penundaan (`time.sleep`) antar batch untuk menghindari pemblokiran.
# - Analisis data lebih lanjut menggunakan pandas (misalnya, distribusi rating atau analisis sentimen).
